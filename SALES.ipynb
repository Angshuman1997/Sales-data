# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Angshuman Bardhan\\Desktop\\Data Set\SALES.csv")
df
# Out:
#       DATE  YEAR       CITY  SALES  CUSTOMER_COUNT
# 0   Jan-21  2019  Bangalore     40              20
# 1   Jan-21  2019       Pune     50              25
# 2   Jan-21  2019    Chennai     60              40
# 3   Jan-21  2019  Bangalore     55              30
# 4   Jan-21  2019       Pune     55              30
# 5   Jan-21  2019    Chennai     40              25
# 6   Jan-22  2019  Bangalore     40              25
# 7   Jan-22  2019       Pune     50              30
# 8   Jan-22  2019    Chennai     60              40
# 9   Jan-22  2019  Bangalore     55              30
# 10  Jan-22  2019       Pune     55              23
# 11  Jan-22  2019    Chennai     40              23

# %%
df['DATE']
# Out:
# 0     Jan-21
# 1     Jan-21
# 2     Jan-21
# 3     Jan-21
# 4     Jan-21
# 5     Jan-21
# 6     Jan-22
# 7     Jan-22
# 8     Jan-22
# 9     Jan-22
# 10    Jan-22
# 11    Jan-22
# Name: DATE, dtype: object

# %%
d1=df.groupby(['CITY','DATE'])['SALES'].sum()
d1
# Out:
# CITY       DATE
# Bangalore  Jan-21     95
#            Jan-22     95
# Chennai    Jan-21    100
#            Jan-22    100
# Pune       Jan-21    105
#            Jan-22    105
# Name: SALES, dtype: int64

# %%
d2=df.groupby(['DATE','CITY'])['CUSTOMER_COUNT'].sum()
d2
# Out:
# DATE    CITY
# Jan-21  Bangalore    50
#         Chennai      65
#         Pune         55
# Jan-22  Bangalore    55
#         Chennai      63
#         Pune         53
# Name: CUSTOMER_COUNT, dtype: int64

# %%
d3=df.groupby(['CITY'])['CUSTOMER_COUNT'].sum()
d3
# Out:
# CITY
# Bangalore    105
# Chennai      128
# Pune         108
# Name: CUSTOMER_COUNT, dtype: int64

# %%
d4=df.groupby(['CITY'])['SALES'].sum()
d4
# Out:
# CITY
# Bangalore    190
# Chennai      200
# Pune         210
# Name: SALES, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels =['Bangalore','Chennai','Pune']
sizes = d4

explode = (0,0,0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',shadow=True,
         startangle=60)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels =['Bangalore','Chennai','Pune']
sizes = d3

explode = (0,0,0.1)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',shadow=True,
         startangle=60)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
